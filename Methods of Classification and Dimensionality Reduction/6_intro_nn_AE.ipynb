# %% [markdown]
# # INTRODUCTION TO NEURAL NETWORKS, PART 1

# %%
import numpy as np
from matplotlib import pyplot as plt

# keras
from keras.datasets import mnist

from keras.models import Sequential, Model
from keras.layers import Dense
from keras import optimizers
from sklearn.linear_model import LinearRegression
from datetime import datetime
# torch
import torch

# %%
# !pip install torchinfo
from torchinfo import summary as torch_summary
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %% [markdown]
# ## Linear Regression (again)
# ### Data:
# We are given $n$ points $(x_1,y_1), \ldots, (x_n,y_n)$.
# Example: $n=200$:

# %%
nr_points=200
np.random.seed(42)
x_train = np.random.rand(nr_points, 1)

a_true=2;
b_true=1;
y_train = b_true + a_true * x_train + .1 * np.random.randn(nr_points, 1)

plt.scatter(x_train,y_train,alpha=0.3)

# LinReg from sklearn, to compare

linr = LinearRegression()
linr.fit(x_train, y_train)
a_skl = linr.coef_[0].item()
b_skl = linr.intercept_.item()

# %% [markdown]
# ## Simplest Neural Network:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In our case $n=1$: $w_1=a$, bias $ = b, g(x)=x$

# %% [markdown]
# # Keras implementation:

# %%
# create model, ONE neuron, input_dim = 1
# activation = linear, actually = do nothing extra.
model_keras = Sequential()
model_keras.add(Dense(1, activation = 'linear', input_dim = 1))  # x's are 1 dimensional

# %%
model_keras.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# use Adam() or SGD() optimizer
#optim = optimizers.SGD()
optim = optimizers.Adam(learning_rate=0.1)

# loss = mean_squared_error. I.e., optimze squared error
model_keras.compile(optimizer=optim, loss = 'mean_squared_error')

# %% [markdown]
# ### TRAIN the model:

# %%
model_keras.fit(x_train, y_train, epochs=200, batch_size=100)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 2s 11ms/step - loss: 7.5244
# Epoch 2/200
# 2/2 [==============================] - 0s 6ms/step - loss: 5.9731
# Epoch 3/200
# 2/2 [==============================] - 0s 5ms/step - loss: 4.6515
# Epoch 4/200
# 2/2 [==============================] - 0s 6ms/step - loss: 3.4998
# Epoch 5/200
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5113
# Epoch 6/200
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7641
# Epoch 7/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1718
# Epoch 8/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7359
# Epoch 9/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4629
# Epoch 10/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2972
# Epoch 11/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2221
# Epoch 12/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2089
# Epoch 13/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2368
# Epoch 14/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2763
# Epoch 15/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3136
# Epoch 16/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3373
# Epoch 17/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3429
# Epoch 18/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3314
# Epoch 19/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3059
# Epoch 20/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2728
# Epoch 21/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2367
# Epoch 22/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2037
# Epoch 23/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1746
# Epoch 24/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1514
# Epoch 25/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1374
# Epoch 26/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1261
# Epoch 27/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1211
# Epoch 28/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1193
# Epoch 29/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1171
# Epoch 30/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1148
# Epoch 31/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1114
# Epoch 32/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1067
# Epoch 33/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1010
# Epoch 34/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0949
# Epoch 35/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0884
# Epoch 36/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0831
# Epoch 37/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0775
# Epoch 38/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0734
# Epoch 39/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0693
# Epoch 40/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0660
# Epoch 41/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0631
# Epoch 42/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0603
# Epoch 43/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0574
# Epoch 44/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0545
# Epoch 45/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0518
# Epoch 46/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0491
# Epoch 47/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0465
# Epoch 48/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0440
# Epoch 49/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0417
# Epoch 50/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0396
# Epoch 51/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0376
# Epoch 52/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0357
# Epoch 53/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0340
# Epoch 54/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0323
# Epoch 55/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0307
# Epoch 56/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0292
# Epoch 57/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0278
# Epoch 58/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0265
# Epoch 59/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0252
# Epoch 60/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0240
# Epoch 61/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0229
# Epoch 62/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0219
# Epoch 63/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0210
# Epoch 64/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0201
# Epoch 65/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0193
# Epoch 66/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0185
# Epoch 67/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0178
# Epoch 68/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 69/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0165
# Epoch 70/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0159
# Epoch 71/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 72/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0149
# Epoch 73/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0144
# Epoch 74/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0140
# Epoch 75/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0136
# Epoch 76/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0132
# Epoch 77/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0129
# Epoch 78/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0126
# Epoch 79/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 80/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0120
# Epoch 81/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 82/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 83/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0113
# Epoch 84/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0112
# Epoch 85/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0110
# Epoch 86/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 87/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0107
# Epoch 88/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 89/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0105
# Epoch 90/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0104
# Epoch 91/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 92/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 93/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0101
# Epoch 94/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0100
# Epoch 95/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0099
# Epoch 96/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0099
# Epoch 97/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0098
# Epoch 98/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0098
# Epoch 99/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0097
# Epoch 100/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0097
# Epoch 101/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 102/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 103/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0096
# Epoch 104/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 105/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0095
# Epoch 106/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0095
# Epoch 107/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0095
# Epoch 108/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0095
# Epoch 109/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0095
# Epoch 110/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0094
# Epoch 111/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0094
# Epoch 112/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0094
# Epoch 113/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0094
# Epoch 114/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 115/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 116/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 117/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 118/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 119/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 120/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 121/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 122/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 123/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 124/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 125/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 126/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 127/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 128/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 129/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 130/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 131/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 132/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 133/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 134/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 135/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 136/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 137/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 138/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 139/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 140/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 141/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 142/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 143/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 144/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 145/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 146/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 147/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 148/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 149/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 150/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 151/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 152/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 153/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 154/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 155/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 156/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 157/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 158/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 159/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 160/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 161/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 162/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 163/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 164/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 165/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 166/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 167/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 168/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 169/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 170/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 171/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 172/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 173/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 174/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 175/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 176/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 177/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 178/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 179/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 180/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 181/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 182/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 183/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 184/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 185/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 186/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 187/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 188/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 189/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 190/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 191/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 192/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 193/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 194/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 195/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 196/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 197/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 198/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 199/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 200/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0093

# %%
y_pred = model_keras.predict(x_train)
# Out:
# 7/7 [==============================] - 0s 4ms/step

# %%
plt.figure(figsize=(6,3))
plt.scatter(x_train,y_train,alpha=0.3)

plt.plot(x_train ,a_skl*x_train +b_skl, label = "sklearn")
plt.plot(x_train,y_pred, label = "NN")

plt.legend()

# %% [markdown]
# ## Torch implementation
#
# To bo consistent with `MoCaDR_List_nr_5_auto_grad.ipynb` one may use `torch`. Note however, that there is no (simple) splitting data into batches (one would need to do it manually, or use `torch.utils.data.DataLoader()`)

# %% [markdown]
# # we need data as tensors

# %%
x_train_tensor = torch.tensor(x_train.astype(float), device=device, dtype=torch.float32 )
y_train_tensor = torch.tensor(y_train.astype(float), device=device, dtype=torch.float32 )

# %%
model =torch.nn.Sequential( torch.nn.Linear(1,1)).to(device)

# %%
torch_summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Sequential                               --
# ├─Linear: 1-1                            2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# =================================================================

# %%
#model(x_train_tensor).T # predicted y's

# %%
optimizer_torch =  torch.optim.SGD(params=model.parameters(),lr=0.2)

# %%
loss_torch = torch.nn.MSELoss()

# %%
loss_torch(x_train_tensor, y_train_tensor)
# Out:
# tensor(2.3168, device='cuda:0')

# %%
n_epochs = 200

for epoch in range(n_epochs):
  y_pred_tensor = model(x_train_tensor)
  loss = loss_torch(y_pred_tensor, y_train_tensor)
  loss.backward()
  optimizer_torch.step()
  optimizer_torch.zero_grad()
  if epoch % 10 == 0:
    print("epoch = ", epoch, ",\t loss = ",loss.item())
# Out:
# epoch =  0 ,	 loss =  3.886791229248047
# epoch =  10 ,	 loss =  0.25365880131721497
# epoch =  20 ,	 loss =  0.14877966046333313
# epoch =  30 ,	 loss =  0.0889228954911232
# epoch =  40 ,	 loss =  0.05476028844714165
# epoch =  50 ,	 loss =  0.035262372344732285
# epoch =  60 ,	 loss =  0.024134162813425064
# epoch =  70 ,	 loss =  0.01778285764157772
# epoch =  80 ,	 loss =  0.014157919213175774
# epoch =  90 ,	 loss =  0.01208903081715107
# epoch =  100 ,	 loss =  0.010908233933150768
# epoch =  110 ,	 loss =  0.010234302841126919
# epoch =  120 ,	 loss =  0.009849665686488152
# epoch =  130 ,	 loss =  0.009630138985812664
# epoch =  140 ,	 loss =  0.009504847228527069
# epoch =  150 ,	 loss =  0.009433338418602943
# epoch =  160 ,	 loss =  0.009392526000738144
# epoch =  170 ,	 loss =  0.009369231760501862
# epoch =  180 ,	 loss =  0.009355936199426651
# epoch =  190 ,	 loss =  0.009348349645733833

# %%
plt.figure(figsize=(6,3))
plt.scatter(x_train,y_train,alpha=0.3)

#plt.plot(x_train ,a_skl*x_train +b_skl, label = "sklearn")

plt.plot(x_train,y_pred, label = "NN Keras")
plt.plot(x_train,y_pred_tensor.cpu().detach().numpy(), label = "NN Torch")


plt.legend()

# %% [markdown]
# # Predicting house prices

# %% [markdown]
# from sklearn.datasets import fetch_california_housing

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# %%
houses = fetch_california_housing()

n_samples, dim = houses.data.shape

houses_data = houses.data
houses_x = houses.data
houses_y = houses.target
#mnist_points =        mnist.data[:max_n]
#mnist_data_classes =  mnist.target[:max_n]
#mnist_classes_names  =      mnist.target_names

# %%
print(np.round(houses_x[:3],2))
print(np.round(houses_y[:3],2))
# Out:
# [[ 8.3300e+00  4.1000e+01  6.9800e+00  1.0200e+00  3.2200e+02  2.5600e+00
#    3.7880e+01 -1.2223e+02]
#  [ 8.3000e+00  2.1000e+01  6.2400e+00  9.7000e-01  2.4010e+03  2.1100e+00
#    3.7860e+01 -1.2222e+02]
#  [ 7.2600e+00  5.2000e+01  8.2900e+00  1.0700e+00  4.9600e+02  2.8000e+00
#    3.7850e+01 -1.2224e+02]]
# [4.53 3.58 3.52]

# %%
x_train, x_test, y_train, y_test = train_test_split(  houses_x, houses_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Goal: train model on x_train, y_train, test afterwards on x_test, y_test

# %%
model_keras = Sequential()
model_keras.add(Dense(1, activation = 'linear', input_dim = 8))  # x's are 8 dimensional
model_keras.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
first_layer_weights = model_keras.layers[0].get_weights()[0]
first_layer_weights
# Out:
# array([[-0.78045714],
#        [-0.7029106 ],
#        [-0.64114714],
#        [-0.01338053],
#        [-0.57333124],
#        [-0.45109376],
#        [ 0.5602733 ],
#        [ 0.10478783]], dtype=float32)

# %%
# use Adam() or SGD() optimizer
#optim = optimizers.SGD(learning_rate=0.001)
optim = optimizers.Adam(learning_rate=0.01, clipnorm=1.,   clipvalue=0.5)

# loss = mean_squared_error. I.e., optimze squared error
model_keras.compile(optimizer=optim, loss = 'mean_squared_error')

# %%
model_keras.fit(x_train, y_train, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 129/129 [==============================] - 2s 2ms/step - loss: 163552.7812
# Epoch 2/50
# 129/129 [==============================] - 0s 2ms/step - loss: 28.1815
# Epoch 3/50
# 129/129 [==============================] - 0s 2ms/step - loss: 11.9013
# Epoch 4/50
# 129/129 [==============================] - 0s 2ms/step - loss: 12.1449
# Epoch 5/50
# 129/129 [==============================] - 0s 2ms/step - loss: 7.6985
# Epoch 6/50
# 129/129 [==============================] - 0s 2ms/step - loss: 8.6751
# Epoch 7/50
# 129/129 [==============================] - 0s 2ms/step - loss: 7.4519
# Epoch 8/50
# 129/129 [==============================] - 0s 2ms/step - loss: 6.5714
# Epoch 9/50
# 129/129 [==============================] - 0s 2ms/step - loss: 5.2061
# Epoch 10/50
# 129/129 [==============================] - 0s 2ms/step - loss: 5.0300
# Epoch 11/50
# 129/129 [==============================] - 0s 2ms/step - loss: 4.6810
# Epoch 12/50
# 129/129 [==============================] - 0s 2ms/step - loss: 4.7075
# Epoch 13/50
# 129/129 [==============================] - 0s 3ms/step - loss: 4.5293
# Epoch 14/50
# 129/129 [==============================] - 0s 3ms/step - loss: 4.6379
# array([[ 5.2291608e-01],
#        [ 1.8132087e-02],
#        [-1.8258855e-01],
#        [ 8.7255728e-01],
#        [-1.3763534e-03],
#        [-1.1403699e-02],
#        [-2.8011356e-02],
#        [ 5.8641389e-04]], dtype=float32)

# %%
y_test_pred = model_keras.predict(x_test)
# Out:
# 129/129 [==============================] - 0s 1ms/step

# %%
lost_houses = np.mean( (y_test-y_test_pred )**2)
print(lost_houses)
# Out:
# 9.157452374433463

# %% [markdown]
# ### Why only one layer and one neuron?
#
# ![t.png](data:image/png;base64,...)

# %% [markdown]
# ### Also, each layer may have different function:
# ![image.png](data:image/png;base64,...)

# %%
model_keras2 =  Sequential([
    Dense(512,  activation='elu', input_shape=(8,), name="lay1"),
    Dense(128,  activation='sigmoid', name="lay2"),
    Dense(1,    activation='linear', name="output"),
])
model_keras2.add(Dense(1, activation = 'linear', input_dim = 8))  # x's are 8 dimensional
model_keras2.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lay1 (Dense)                (None, 512)               4608
#
#  lay2 (Dense)                (None, 128)               65664
#
#  output (Dense)              (None, 1)                 129
#
#  dense_8 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 70403 (275.01 KB)
# Trainable params: 70403 (275.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# use Adam() or SGD() optimizer
#optim = optimizers.SGD(learning_rate=0.001)
optim = optimizers.Adam(learning_rate=0.01, clipnorm=1.,   clipvalue=0.5)

# loss = mean_squared_error. I.e., optimze squared error
model_keras2.compile(optimizer=optim, loss = 'mean_squared_error')

# %%
model_keras2.fit(x_train, y_train, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 129/129 [==============================] - 2s 3ms/step - loss: 1.3831
# Epoch 2/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3476
# Epoch 3/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3500
# Epoch 4/50
# 129/129 [==============================] - 0s 4ms/step - loss: 1.3463
# Epoch 5/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3446
# Epoch 6/50
# 129/129 [==============================] - 1s 4ms/step - loss: 1.3505
# Epoch 7/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3492
# Epoch 8/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3453
# Epoch 9/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3494
# Epoch 10/50
# 129/129 [==============================] - 1s 4ms/step - loss: 1.3434
# Epoch 11/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3585
# Epoch 12/50
# 129/129 [==============================] - 1s 4ms/step - loss: 1.3453
# Epoch 13/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3426
# Epoch 14/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3527
# Epoch 15/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3528
# Epoch 16/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3517
# Epoch 17/50
# 129/129 [==============================] - 0s 4ms/step - loss: 1.3516
# Epoch 18/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3448
# Epoch 19/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3449
# Epoch 20/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3447
# Epoch 21/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3517
# Epoch 22/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3483
# Epoch 23/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3450
# Epoch 24/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3488
# Epoch 25/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3487
# Epoch 26/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3536
# Epoch 27/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3437
# Epoch 28/50
# 129/129 [==============================] - 0s 4ms/step - loss: 1.3447
# Epoch 29/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3430
# Epoch 30/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3474
# Epoch 31/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3465
# Epoch 32/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3445
# Epoch 33/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3504
# Epoch 34/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3479
# Epoch 35/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3454
# Epoch 36/50
# 129/129 [==============================] - 0s 3ms/step - loss: 1.3505
# Epoch 37/50
# 129/129 [==============================] - 0s 4ms/step - loss: 1.3440
# Epoch 38/50
# 129/129 [==============================] - 0s 4ms/step - loss: 1.3525
# Epoch 39/50
# 129/129 [==============================] - 1s 4ms/step - loss: 1.3401
# Epoch 40/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3481
# Epoch 41/50
# 129/129 [==============================] - 1s 8ms/step - loss: 1.3486
# Epoch 42/50
# 129/129 [==============================] - 1s 9ms/step - loss: 1.3463
# Epoch 43/50
# 129/129 [==============================] - 1s 6ms/step - loss: 1.3486
# Epoch 44/50
# 129/129 [==============================] - 1s 6ms/step - loss: 1.3524
# Epoch 45/50
# 129/129 [==============================] - 1s 6ms/step - loss: 1.3511
# Epoch 46/50
# 129/129 [==============================] - 1s 6ms/step - loss: 1.3667
# Epoch 47/50
# 129/129 [==============================] - 1s 6ms/step - loss: 1.3476
# Epoch 48/50
# 129/129 [==============================] - 1s 6ms/step - loss: 1.3617
# Epoch 49/50
# 129/129 [==============================] - 1s 6ms/step - loss: 1.3491
# Epoch 50/50
# 129/129 [==============================] - 1s 5ms/step - loss: 1.3525

# %%
x_test.shape
# Out:
# (4128, 8)

# %%
y_test_pred2 = model_keras2.predict(x_test)
lost_houses2 = np.mean( (y_test-y_test_pred2 )**2)
print(lost_houses2)
# Out:
# 129/129 [==============================] - 1s 3ms/step
# 1.3130616614148138

# %% [markdown]
# # AUTOENCODERS

# %% [markdown]
# Again, MNIST images:

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
n_samples_train, h, w =     x_train.shape
n_samples_test, _, _ =      x_test.shape

image_size = h*w

x_train = x_train.reshape(x_train.shape[0], 784) / 255
x_test = x_test.reshape(x_test.shape[0], 784) / 255

# %%
print("n_samples_train, h, w, image_size = ",n_samples_train, h, w ,image_size)
# Out:
# n_samples_train, h, w, image_size =  60000 28 28 784

# %%
f = plt.figure()
f.add_subplot(1,4, 1)
img=x_train[0].reshape(h,w)
plt.imshow(img,cmap='gray')
img=x_train[12].reshape(h,w)
f.add_subplot(1,4, 2)
plt.imshow(img,cmap='gray')
f.add_subplot(1,4, 3)
img=x_train[132].reshape(h,w)
plt.imshow(img,cmap='gray')
f.add_subplot(1,4, 4)
img=x_train[52].reshape(h,w)
plt.imshow(img,cmap='gray')
plt.show()

# %% [markdown]
# # Goal: "compress" each image to 2d points, later "recover" images from those

# %% [markdown]
# # PCA 2d points:

# %%
mu = x_train.mean(axis=0)
U,s,V = np.linalg.svd(x_train - mu, full_matrices=False)
Zpca = np.dot(x_train - mu, V.transpose())

Rpca = np.dot(Zpca[:,:2], V[:2,:]) + mu    # reconstruction

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.title('PCA')
plt.scatter(Zpca[:5000,0], Zpca[:5000,1], c=y_train[:5000], s=8, cmap='tab10')

# %% [markdown]
# # PCA: images reconstructed from 2d points

# %%
plt.figure(figsize=(9,3))
toPlot = (x_train, Rpca )
for i in range(10):
    for j in range(2):
        ax = plt.subplot(3, 10, 10*j+i+1)
        plt.imshow(np.array(toPlot[j][i,:]).reshape(28,28), interpolation="nearest",
                   vmin=0, vmax=1)
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

#plt.tight_layout()

# %%
PCA_err = np.sum((x_train-Rpca)**2)/(n_samples_train*image_size)
print('PCA reconstruction error with 2 PCs: ' + str(round(PCA_err,3)));
# Out:
# PCA reconstruction error with 2 PCs: 0.056

# %% [markdown]
# # Autoencoder AE
# ## Network:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
encoder = Sequential([
    Dense(2,   activation='elu', input_shape=(784,)),
])

decoder = Sequential([
    Dense(784,  activation='relu', input_shape=(2,)),
])

AE_model_small = Model(inputs=encoder.input, outputs=decoder(encoder.output))
AE_model_small.compile(loss='mean_squared_error', optimizer = optimizers.Adam())

# %%
AE_model_small.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27_input (InputLayer  [(None, 784)]             0
#  )
#
#  dense_27 (Dense)            (None, 2)                 1570
#
#  sequential_20 (Sequential)  (None, 784)               2352
#
# =================================================================
# Total params: 3922 (15.32 KB)
# Trainable params: 3922 (15.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Above is equivalent to:

# %%
AE_model_small_v2 =  Sequential([
    Dense(2,  activation='elu', input_shape=(784,), name="lay1"),
    Dense(784,    activation='linear', name="output"),
])
AE_model_small_v2.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lay1 (Dense)                (None, 2)                 1570
#
#  output (Dense)              (None, 784)               2352
#
# =================================================================
# Total params: 3922 (15.32 KB)
# Trainable params: 3922 (15.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
start_time = datetime.now()

AE_model_small.fit(x_train, x_train, batch_size=128, epochs=5, verbose=1)

time_elapsed = datetime.now() - start_time
print('TRAINING TIME (hh:mm:ss.ms) {}'.format(time_elapsed))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 3s 4ms/step - loss: 0.0755
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0679
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0672
# Epoch 4/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0660
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0654
# TRAINING TIME (hh:mm:ss.ms) 0:00:10.220355

# %%
x_train_reconstr  = AE_model_small(x_train)
AE_small_error= np.sum((x_train-x_train_reconstr)**2)/(n_samples_train*image_size)
print('AE_small reconstruction error with size 2: ' + str(round(AE_small_error,3)));
print('PCA reconstruction error with 2 PCs: ' + str(round(PCA_err,3)));
# Out:
# AE_small reconstruction error with size 2: 0.065
# PCA reconstruction error with 2 PCs: 0.056

# %%
x_train_encoded = encoder(x_train)
print(x_train_encoded.shape)
# Out:
# (60000, 2)

# %% [markdown]
# # Why encoder and decoder have only one layer?
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
encoder_larger1 = Sequential([
    Dense(512,  activation='elu', input_shape=(784,), name="lay1"),
    Dense(128,  activation='elu'),
    Dense(2,    activation='linear', name="bottleneck"),
])

decoder_larger1 = Sequential([
    Dense(128,  activation='elu', input_shape=(2,)),
    Dense(512,  activation='elu'),
    Dense(784,  activation='sigmoid'),
])

AE_larger1 = Model(inputs=encoder_larger1.input, outputs=decoder_larger1(encoder_larger1.output))
AE_larger1.compile(loss='mean_squared_error', optimizer = optimizers.Adam())

# %%
AE_larger1.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lay1_input (InputLayer)     [(None, 784)]             0
#
#  lay1 (Dense)                (None, 512)               401920
#
#  dense_9 (Dense)             (None, 128)               65664
#
#  bottleneck (Dense)          (None, 2)                 258
#
#  sequential_9 (Sequential)   (None, 784)               468624
#
# =================================================================
# Total params: 936466 (3.57 MB)
# Trainable params: 936466 (3.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
start_time = datetime.now()

AE_larger1.fit(x_train, x_train, batch_size=128, epochs=10, verbose=1)

time_elapsed = datetime.now() - start_time
print('TRAINING TIME (hh:mm:ss.ms) {}'.format(time_elapsed))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 4s 4ms/step - loss: 0.0566
# Epoch 2/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0465
# Epoch 3/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0440
# Epoch 4/10
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0425
# Epoch 5/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0417
# Epoch 6/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0410
# Epoch 7/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0403
# Epoch 8/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0396
# Epoch 9/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0391
# Epoch 10/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0387
# TRAINING TIME (hh:mm:ss.ms) 0:00:42.851913

# %% [markdown]
# # Q6.0 (extra, 0 points)
# * Go to `Runtime -> Change runtime type` and try (not always available) to re-run above and compare training time.

# %%
x_train_reconstr_larger1 = AE_larger1(x_train)
x_train_encoded_larger1 = encoder_larger1(x_train)

# %%
AE_larger1_err = np.sum((x_train-x_train_reconstr_larger1)**2)/(n_samples_train*image_size)

# %%
print('AR_larger1  reconstruction error with size 2: ' + str(round(AE_larger1_err,3)));
print('AE_small reconstruction error with size 2: ' + str(round(AE_small_error,3)));
print('PCA reconstruction error with 2 PCs: ' + str(round(PCA_err,3)));
# Out:
# AR_larger1  reconstruction error with size 2: 0.038
# AE_small reconstruction error with size 2: 0.062
# PCA reconstruction error with 2 PCs: 0.056

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.title('PCA')
plt.scatter(Zpca[:5000,0], Zpca[:5000,1], c=y_train[:5000], s=8, cmap='tab10')
plt.gca().get_xaxis().set_ticklabels([])
plt.gca().get_yaxis().set_ticklabels([])

plt.subplot(132)
plt.title('AE (small)')
plt.scatter(x_train_encoded[:5000,0], x_train_encoded[:5000,1], c=y_train[:5000], s=8, cmap='tab10')
plt.gca().get_xaxis().set_ticklabels([])
plt.gca().get_yaxis().set_ticklabels([])

plt.subplot(133)
plt.title('AE_larger1 (keras)')
plt.scatter(x_train_encoded_larger1[:5000,0], x_train_encoded_larger1[:5000,1], c=y_train[:5000], s=8, cmap='tab10')
plt.gca().get_xaxis().set_ticklabels([])
plt.gca().get_yaxis().set_ticklabels([])



plt.tight_layout()

# %% [markdown]
# Reconstructed images:
#
#
# *   Row 1 = original images
# *   Row 2 = PCA
# *   Row 3 = Autoencoder (small)
# *   Row 4 = Autoencoder_larger1

# %%
plt.figure(figsize=(9,3))
toPlot = (x_train, Rpca, x_train_reconstr,x_train_reconstr_larger1)
for i in range(10):
    for j in range(4):
        ax = plt.subplot(4, 10, 10*j+i+1)
        plt.imshow(np.array(toPlot[j][i,:]).reshape(28,28), interpolation="nearest",
                   vmin=0, vmax=1)
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

plt.tight_layout()

# %% [markdown]
# # Q6.1
# * Construct in a similar way Autoencoder with $r=3$ neurons "in the middle" and display 3d images
# * Repeat the same with some larger $r>3$, display several reconstructed images and compute the reconstruction error

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Dense
from keras import optimizers
from datetime import datetime


encoder_larger2 = Sequential([
    Dense(512,  activation='elu', input_shape=(784,), name="lay1"),
    Dense(128,  activation='elu'),
    Dense(3,    activation='linear', name="bottleneck"),
])


decoder_larger2 = Sequential([
    Dense(128,  activation='elu', input_shape=(3,)),
    Dense(512,  activation='elu'),
    Dense(784,  activation='sigmoid'),
])


AE_larger2 = Model(inputs=encoder_larger2.input, outputs=decoder_larger2(encoder_larger2.output))
AE_larger2.compile(loss='mean_squared_error', optimizer=optimizers.Adam())

start_time = datetime.now()

AE_larger2.fit(x_train, x_train, batch_size=128, epochs=10, verbose=1)

time_elapsed = datetime.now() - start_time
print('TRAINING TIME (hh:mm:ss.ms) {}'.format(time_elapsed))


x_train_encoded_larger2 = encoder_larger2.predict(x_train)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 7s 9ms/step - loss: 0.0496
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0386
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0361
# Epoch 4/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0348
# Epoch 5/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0338
# Epoch 6/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0331
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0326
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0321
# Epoch 9/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0317
# Epoch 10/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0314
# TRAINING TIME (hh:mm:ss.ms) 0:00:40.869958
# 1875/1875 [==============================] - 3s 2ms/step

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_train_encoded_larger2[:5000, 0], x_train_encoded_larger2[:5000, 1], x_train_encoded_larger2[:5000, 2], c=y_train[:5000], s=8, cmap='tab10' )
ax.set_title('Encoded Representations')
ax.set_xlabel('Encoded Dimension 1')
ax.set_ylabel('Encoded Dimension 2')
ax.set_zlabel('Encoded Dimension 3')
plt.show()

# %%
# Plot reconstructed and real images for x_train_reconstr_larger1
plt.figure(figsize=(10, 4))
for i in range(10):
    # Original image
    ax = plt.subplot(2, 10, i + 1)
    plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
    if i == 0:
        ax.set_title('Original')

    # Reconstructed image
    ax = plt.subplot(2, 10, i + 11)
    plt.imshow(x_train_reconstr_larger2[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
    if i == 0:
        ax.set_title('Reconstructed (larger2)')

plt.tight_layout()
plt.show()

# %%
import numpy as np

mse_reconstr_larger2 = np.mean(np.square(x_train - x_train_reconstr_larger2))
print("Reconstruction loss for x_train_reconstr_larger2:", mse_reconstr_larger2)
# Out:
# Reconstruction loss for x_train_reconstr_larger2: 0.03096054844742281

# %%
import plotly.graph_objs as go
import plotly.io as pio
import matplotlib.cm as cm

tab10_colors = cm.tab10(np.linspace(0, 1, 10))


tab10_colors_plotly = ['rgb' + str(tuple(int(255 * x) for x in color[:3])) for color in tab10_colors]


trace = go.Scatter3d(
    x=x_train_encoded_larger2[:5000, 0],
    y=x_train_encoded_larger2[:5000, 1],
    z=x_train_encoded_larger2[:5000, 2],
    mode='markers',
    marker=dict(
        size=2,
        color=y_train[:5000],
        colorscale=tab10_colors_plotly,
        opacity=1
    )
)

# Create layout
layout = go.Layout(
    title='Encoded Representations',
    scene=dict(
        xaxis=dict(title='Encoded Dimension 1'),
        yaxis=dict(title='Encoded Dimension 2'),
        zaxis=dict(title='Encoded Dimension 3')
    )
)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Show plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7d77016e-7d5f-4c56-8c6c-d27b8886233e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d77016e-7d5f-4c56-8c6c-d27b8886233e")) {                    Plotly.newPlot(                        "7d77016e-7d5f-4c56-8c6c-d27b8886233e",                        [{"marker":{"color":[5,0,4,1,9,2,1,3,1,4,3,5,3,6,1,7,2,8,6,9,4,0,9,1,1,2,4,3,2,7,3,8,6,9,0,5,6,0,7,6,1,8,7,9,3,9,8,5,9,3,3,0,7,4,9,8,0,9,4,1,4,4,6,0,4,5,6,1,0,0,1,7,1,6,3,0,2,1,1,7,9,0,2,6,7,8,3,9,0,4,6,7,4,6,8,0,7,8,3,1,5,7,1,7,1,1,6,3,0,2,9,3,1,1,0,4,9,2,0,0,2,0,2,7,1,8,6,4,1,6,3,4,5,9,1,3,3,8,5,4,7,7,4,2,8,5,8,6,7,3,4,6,1,9,9,6,0,3,7,2,8,2,9,4,4,6,4,9,7,0,9,2,9,5,1,5,9,1,2,3,2,3,5,9,1,7,6,2,8,2,2,5,0,7,4,9,7,8,3,2,1,1,8,3,6,1,0,3,1,0,0,1,7,2,7,3,0,4,6,5,2,6,4,7,1,8,9,9,3,0,7,1,0,2,0,3,5,4,6,5,8,6,3,7,5,8,0,9,1,0,3,1,2,2,3,3,6,4,7,5,0,6,2,7,9,8,5,9,2,1,1,4,4,
2,2,3,9,4,9,5,0,6,7,7,1,8,0,2,2,0,4,1,1,2,7,3,9,7,2,8,1,9,5,8,8,1,9,8,3,1,6,5,7,4,2,7,0,3,0,4,1,1,7,9,1,1,8,5,7,5,0,6,6,0,4,1,2,3,4,4,6,8,0,9,5,8,7,0,3,5,4,5,9,6,7,1,9,6,1,3,8,3,9,1,2,7,7,7,0,2,3,1,1,4,2,5,6,0,9,6,2,8,9,2,3,3,6,9,1,4,3,3,0,7,7,1,7,7,3,6,4,9,5,4,4,2,7,9,0,9,8,4,4,9,1,2,4,9,3,0,4,1,6,2,6,3,7,4,2,6,6,7,1,8,9,0,4,1,4,2,1,3,6,4,6,7,5,8,7,0,5,1,4,2,8,4,7,7,3,8,4,9,5,8,6,7,3,4,6,7,1,7,4,3,3,9,8,8,1,8,6,3,1,1,3,5,2,8,4,2,9,7,1,4,8,2,9,6,4,1,3,4,2,5,2,5,6,8,0,6,2,4,9,4,9,4,5,1,5,8,4,7,9,5,9,5,9,1,5,8,3,9,9,1,8,3,8,6,5,2,7,2,7,6,0,9,7,9,4,6,0,5,3,5,7,3,9,3,6,8,3,1,7,6,5,5,7,6,5,8,2,1,7,9,2,7,3,6,7,8,5,3,7,7,8,4,0,7,3,0,6,3,9,7,1,9,5,3,6,0,9,2,8,0,9,1,6,0,0,1,9,0,0,4,2,1,7,0,3,4,4,7,5,9,8,2,0,0,8,6,2,2,7,6,1,2,9,2,6,9,7,9,5,0,8,1,5,2,4,3,9,4,7,5,6,6,7,7,6,8,5,9,7,0,6,1,9,2,3,3,5,4,3,5,8,6,3,7,2,8,4,9,5,0,2,1,4,2,4,3,1,7,1,8,0,9,6,8,1,9,4,4,9,1,8,9,6,5,5,3,3,0,1,4,3,8,3,4,2,0,7,5,5,1,8,5,3,4,6,0,5,7,2,6,6,0,1,1,4,7,9,0,0,6,6,8,6,9,4,5,2,4,0,7,5,6,5,0,9,8,6,1,9,7,5,7,5,1,1,3,0,2,0,3,8,1,6,4,6,2,6,4,8,8,1,4,4,7,1,2,2,3,9,6,4,9,5,6,2,3,9,2,6,2,7,4,3,6,4,9,7,0,2,2,9,5,4,5,0,1,4,3,6,3,2,9,7,5,3,7,0,9,5,8,3,2,0,1,8,3,0,1,2,3,4,0,0,1,7,2,9,3,9,4,2,5,8,6,7,7,9,8,9,9,2,0,0,1,4,2,4,3,9,4,3,5,7,6,5,7,1,8,6,9,3,0,4,1,2,2,5,3,7,4,1,7,7,8,1,9,2,3,2,4,0,1,8,4,3,6,5,6,4,7,9,3,1,3,0,2,1,1,0,9,9,4,6,7,6,3,5,5,4,4,6,9,1,1,3,1,1,0,5,1,4,4,6,6, ...

# %%
import plotly.graph_objs as go
import plotly.io as pio

# Create a trace
trace = go.Scatter3d(
    x=x_train_encoded_larger2[:5000, 0],
    y=x_train_encoded_larger2[:5000, 1],
    z=x_train_encoded_larger2[:5000, 2],
    mode='markers',
    marker=dict(
        size=2,
        color=y_train[:5000],
        colorscale='Rainbow',
        opacity=1
    )
)

# Create layout
layout = go.Layout(
    title='Encoded Representations',
    scene=dict(
        xaxis=dict(title='Encoded Dimension 1'),
        yaxis=dict(title='Encoded Dimension 2'),
        zaxis=dict(title='Encoded Dimension 3')
    )
)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Show plot
pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id
8,2,0,0,8,6,2,2,7,6,1,2,9,2,6,9,7,9,5,0,8,1,5,2,4,3,9,4,7,5,6,6,7,7,6,8,5,9,7,0,6,1,9,2,3,3,5,4,3,5,8,6,3,7,2,8,4,9,5,0,2,1,4,2,4,3,1,7,1,8,0,9,6,8,1,9,4,4,9,1,8,9,6,5,5,3,3,0,1,4,3,8,3,4,2,0,7,5,5,1,8,5,3,4,6,0,5,7,2,6,6,0,1,1,4,7,9,0,0,6,6,8,6,9,4,5,2,4,0,7,5,6,5,0,9,8,6,1,9,7,5,7,5,1,1,3,0,2,0,3,8,1,6,4,6,2,6,4,8,8,1,4,4,7,1,2,2,3,9,6,4,9,5,6,2,3,9,2,6,2,7,4,3,6,4,9,7,0,2,2,9,5,4,5,0,1,4,3,6,3,2,9,7,5,3,7,0,9,5,8,3,2,0,1,8,3,0,1,2,3,4,0,0,1,7,2,9,3,9,4,2,5,8,6,7,7,9,8,9,9,2,0,0,1,4,2,4,3,9,4,3,5,7,6,5,7,1,8,6,9,3,0,4,1,2,2,5,3,7,4,1,7,7,8,1,9,2,3,2,4,0,1,8,4,3,6,5,6,4,7,9,3,1,3,0,2,1,1,0,9,9,4,6,7,6,3,5,5,4,4,6,9,1,1,3,1,1,0,5,1,4,4,6,6, ...

# %% [markdown]
# # AUTOENCODERS FOR DENOSING IMAGES

# %% [markdown]
# # Add noise to mnist:

# %%
noise_level=0.5 #początkowo było 0.25

x_train_noisy = x_train+noise_level*np.random.normal(loc=0.0, scale=1.0, size = x_train.shape)
x_test_noisy = x_test+noise_level*np.random.normal(loc=0.0, scale=1.0, size = x_test.shape)

# %%
plt.figure(figsize=(10,12))
for i in range(6):
  ax = plt.subplot(12, 6, i+1)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.imshow(x_train[i].reshape(28,28), interpolation="nearest", vmin=0, vmax=1)
  ax = plt.subplot(12, 6, 6+i+1)
  plt.imshow(x_train_noisy[i].reshape(28,28), interpolation="nearest", vmin=0, vmax=1)
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.tight_layout()

# %% [markdown]
# # Q6.2
# * Construct Autoencoder (similar to AE_larger1, but may have larger $r$) so that: on input it gets noisy images from training set (i.e., `x_train_noisy`), the output is compared to original unnoised image (i.e., from `x_train`, use `mean_squared_error`).
# * Display some of your denoised images
# * Unnoise images `x_test_noisy` and compare (MSE) with `x_test`
# * Play aroudn: try different number of hidden layers, different activation functions, etc. For your best network try to apply it for larger values of `noise_level`

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers

def denoising_autoencoder(input_shape):
    model = Sequential([
        Dense(512, activation='elu', input_shape=input_shape),
        Dense(256, activation='elu'),
        Dense(128, activation='elu'),
        Dense(32, activation='elu'),
        Dense(128, activation='elu'),
        Dense(256, activation='elu'),
        Dense(512, activation='elu'),
        Dense(input_shape[0], activation='sigmoid')
    ])
    return model

input_shape = (784,)
autoencoder = denoising_autoencoder(input_shape)

autoencoder.compile(loss='mean_squared_error', optimizer='adam')

autoencoder.fit(x_train_noisy, x_train, epochs=10, batch_size=128, shuffle=True)

denoised_images = autoencoder.predict(x_test_noisy)
for i in range(10):
    plt.subplot(1, 3, 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title('Noisy Image')
    plt.subplot(1, 3, 2)
    plt.imshow(denoised_images[i].reshape(28, 28), cmap='gray')
    plt.title('Denoised Image')
    plt.subplot(1, 3, 3)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title('True Image')
    plt.show()

mse = np.mean(np.square(x_test - denoised_images))
print("Mean Squared Error (MSE) between denoised images and original unnoised images:", mse)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 22s 34ms/step - loss: 0.0371
# Epoch 2/10
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0219
# Epoch 3/10
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0187
# Epoch 4/10
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0170
# Epoch 5/10
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0159
# Epoch 6/10
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0150
# Epoch 7/10
# 469/469 [==============================] - 15s 33ms/step - loss: 0.0143
# Epoch 8/10
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0138
# Epoch 9/10
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0133
# Epoch 10/10
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0128
# 313/313 [==============================] - 2s 5ms/step
# Mean Squared Error (MSE) between denoised images and original unnoised images: 0.015872683049832848

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers

def denoising_autoencoder(input_shape):
    model = Sequential([
        Dense(512, activation='elu', input_shape=input_shape),

        Dense(4, activation='elu'),

        Dense(512, activation='elu'),
        Dense(input_shape[0], activation='sigmoid')
    ])
    return model

input_shape = (784,)
autoencoder = denoising_autoencoder(input_shape)

autoencoder.compile(loss='mean_squared_error', optimizer='adam')

autoencoder.fit(x_train_noisy, x_train, epochs=10, batch_size=128, shuffle=True)

denoised_images = autoencoder.predict(x_test_noisy)
for i in range(10):
    plt.subplot(1, 3, 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title('Noisy Image')
    plt.subplot(1, 3, 2)
    plt.imshow(denoised_images[i].reshape(28, 28), cmap='gray')
    plt.title('Denoised Image')
    plt.subplot(1, 3, 3)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title('True Image')
    plt.show()

mse = np.mean(np.square(x_test - denoised_images))
print("Mean Squared Error (MSE) between denoised images and original unnoised images:", mse)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 11s 20ms/step - loss: 0.0613
# Epoch 2/10
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0531
# Epoch 3/10
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0506
# Epoch 4/10
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0491
# Epoch 5/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0481
# Epoch 6/10
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0472
# Epoch 7/10
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0465
# Epoch 8/10
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0459
# Epoch 9/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0454
# Epoch 10/10
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0450
# 313/313 [==============================] - 1s 4ms/step
# Mean Squared Error (MSE) between denoised images and original unnoised images: 0.04558779949989224
